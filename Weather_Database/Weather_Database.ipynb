# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np

# Import the random module.
import random

# Import the API key.
from config import weather_api_key2

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key2
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2496cbfd2729e97cdd628a599160f12d

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | champerico
# Processing Record 2 of Set 1 | vanimo
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | tortoli
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | imbituba
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | golyshmanovo
# Processing Record 9 of Set 1 | bilma
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | kamenka
# Processing Record 14 of Set 1 | mehamn
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | kahului
# Processing Record 17 of Set 1 | grand gaube
# Processing Record 18 of Set 1 | ahipara
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | nambucca heads
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | westport
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | nuuk
# Processing Record 25 of Set 1 | rio grande
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | morondava
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 1 | tobol
# Processing Record 33 of Set 1 | ramgarh
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | san patricio
# Processing Record 36 of Set 1 | belyy yar
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | san onofre
# Processing Record 39 of Set 1 | ponta do sol
# Processing Record 40 of Set 1 | sao jose da coroa grande
# Processing Record 41 of Set 1 | la asuncion
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | kruisfontein
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | kuryk
# Processing Record 46 of Set 1 | deputatskiy
# Processing Record 47 of Set 1 | saint-georges
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | jilin
# Processing Record 50 of Set 1 | shiraz
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | quatre cocos
# Processing Record 3 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 2 | ambanja
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | cape coral
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 2 | san cristobal
# Processing Record 12 of Set 2 | macapa
# Processing Record 13 of Set 2 | iqaluit
# Processing Record 14 of Set 2 | trairi
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | sabang
# Processing Record 17 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | sulphur springs
# Processing Record 21 of Set 2 | fairbanks
# Processing Record 22 of Set 2 | san quintin
# Processing Record 23 of Set 2 | ginir
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | sao luiz gonzaga
# Processing Record 26 of Set 2 | belmopan
# Processing Record 27 of Set 2 | jizan
# Processing Record 28 of Set 2 | asau
# Processing Record 29 of Set 2 | mount isa
# Processing Record 30 of Set 2 | webuye
# Processing Record 31 of Set 2 | mercedes
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | airai
# Processing Record 34 of Set 2 | erzin
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | hajnowka
# Processing Record 38 of Set 2 | beringovskiy
# Processing Record 39 of Set 2 | anadyr
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | tuatapere
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | sao goncalo
# Processing Record 45 of Set 2 | algiers
# Processing Record 46 of Set 2 | nanzhang
# Processing Record 47 of Set 2 | leningradskiy
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | raga
# Processing Record 50 of Set 2 | sechura
# Processing Record 1 of Set 3 | luganville
# Processing Record 2 of Set 3 | shimanovsk
# Processing Record 3 of Set 3 | busselton
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | clyde river
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | cururupu
# Processing Record 8 of Set 3 | esperance
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | smithers
# Processing Record 12 of Set 3 | mayumba
# Processing Record 13 of Set 3 | omboue
# Processing Record 14 of Set 3 | hasaki
# Processing Record 15 of Set 3 | maine-soroa
# Processing Record 16 of Set 3 | provideniya
# Processing Record 17 of Set 3 | hirara
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | clearwater
# Processing Record 22 of Set 3 | coquimbo
# Processing Record 23 of Set 3 | diego de almagro
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | meulaboh
# Processing Record 26 of Set 3 | ndiekro
# City not found. Skipping...
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | rosetta
# Processing Record 29 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 3 | tiksi
# Processing Record 31 of Set 3 | tautira
# Processing Record 32 of Set 3 | ginda
# Processing Record 33 of Set 3 | ilulissat
# Processing Record 34 of Set 3 | ampanihy
# Processing Record 35 of Set 3 | salalah
# Processing Record 36 of Set 3 | tarakan
# Processing Record 37 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 3 | nantucket
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 3 | longyearbyen
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | khorramshahr
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | menongue
# Processing Record 46 of Set 3 | skelleftea
# Processing Record 47 of Set 3 | pavilosta
# Processing Record 48 of Set 3 | llangefni
# Processing Record 49 of Set 3 | antalaha
# Processing Record 50 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 1 of Set 4 | barrow
# Processing Record 2 of Set 4 | tual
# Processing Record 3 of Set 4 | saint george
# Processing Record 4 of Set 4 | north platte
# Processing Record 5 of Set 4 | fortuna
# Processing Record 6 of Set 4 | shahr-e kord
# Processing Record 7 of Set 4 | madison
# Processing Record 8 of Set 4 | siva
# Processing Record 9 of Set 4 | guerrero negro
# Processing Record 10 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 4 | la sarre
# Processing Record 12 of Set 4 | jiuquan
# Processing Record 13 of Set 4 | puerto carreno
# Processing Record 14 of Set 4 | ancud
# Processing Record 15 of Set 4 | egvekinot
# Processing Record 16 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 4 | marsa matruh
# Processing Record 18 of Set 4 | shimoda
# Processing Record 19 of Set 4 | pskov
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | stornoway
# Processing Record 23 of Set 4 | bonthe
# Processing Record 24 of Set 4 | los llanos de aridane
# Processing Record 25 of Set 4 | xifeng
# Processing Record 26 of Set 4 | rapid valley
# Processing Record 27 of Set 4 | pathein
# Processing Record 28 of Set 4 | port blair
# Processing Record 29 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 4 | aloleng
# Processing Record 31 of Set 4 | carutapera
# Processing Record 32 of Set 4 | dwarka
# Processing Record 33 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 4 | saskylakh
# Processing Record 35 of Set 4 | buraydah
# Processing Record 36 of Set 4 | lowicz
# Processing Record 37 of Set 4 | banda aceh
# Processing Record 38 of Set 4 | proletariy
# Processing Record 39 of Set 4 | atuona
# Processing Record 40 of Set 4 | palana
# Processing Record 41 of Set 4 | severo-kurilsk
# Processing Record 42 of Set 4 | muros
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | srednekolymsk
# Processing Record 45 of Set 4 | yeppoon
# Processing Record 46 of Set 4 | the valley
# Processing Record 47 of Set 4 | anar darreh
# City not found. Skipping...
# Processing Record 48 of Set 4 | chardara
# Processing Record 49 of Set 4 | norman wells
# Processing Record 50 of Set 4 | abidjan
# Processing Record 1 of Set 5 | castro
# Processing Record 2 of Set 5 | grindavik
# Processing Record 3 of Set 5 | chapais
# Processing Record 4 of Set 5 | coahuayana
# Processing Record 5 of Set 5 | komsomolskiy
# Processing Record 6 of Set 5 | hobyo
# Processing Record 7 of Set 5 | saint anthony
# Processing Record 8 of Set 5 | tezu
# Processing Record 9 of Set 5 | korla
# Processing Record 10 of Set 5 | mujiayingzi
# Processing Record 11 of Set 5 | san rafael
# Processing Record 12 of Set 5 | albina
# Processing Record 13 of Set 5 | zhicheng
# Processing Record 14 of Set 5 | lethem
# Processing Record 15 of Set 5 | hithadhoo
# Processing Record 16 of Set 5 | heidenreichstein
# Processing Record 17 of Set 5 | thinadhoo
# Processing Record 18 of Set 5 | zhezkazgan
# Processing Record 19 of Set 5 | lavrentiya
# Processing Record 20 of Set 5 | carnarvon
# Processing Record 21 of Set 5 | margate
# Processing Record 22 of Set 5 | ganzhou
# Processing Record 23 of Set 5 | moletai
# Processing Record 24 of Set 5 | morros
# Processing Record 25 of Set 5 | tecoanapa
# Processing Record 26 of Set 5 | gimbi
# Processing Record 27 of Set 5 | sao filipe
# Processing Record 28 of Set 5 | olafsvik
# Processing Record 29 of Set 5 | fuyu
# Processing Record 30 of Set 5 | ovalle
# Processing Record 31 of Set 5 | acari
# Processing Record 32 of Set 5 | reconquista
# Processing Record 33 of Set 5 | matane
# Processing Record 34 of Set 5 | swan hill
# Processing Record 35 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 5 | coihaique
# Processing Record 37 of Set 5 | nikolskoye
# Processing Record 38 of Set 5 | nampula
# Processing Record 39 of Set 5 | cabo san lucas
# Processing Record 40 of Set 5 | naze
# Processing Record 41 of Set 5 | souillac
# Processing Record 42 of Set 5 | togur
# Processing Record 43 of Set 5 | akdepe
# Processing Record 44 of Set 5 | sampit
# Processing Record 45 of Set 5 | kisangani
# Processing Record 46 of Set 5 | chiang khong
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | riyadh
# Processing Record 49 of Set 5 | carauari
# Processing Record 50 of Set 5 | hay river
# Processing Record 1 of Set 6 | luderitz
# Processing Record 2 of Set 6 | vila franca do campo
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | flinders
# Processing Record 5 of Set 6 | palampur
# Processing Record 6 of Set 6 | acajutla
# Processing Record 7 of Set 6 | toftir
# City not found. Skipping...
# Processing Record 8 of Set 6 | geraldton
# Processing Record 9 of Set 6 | kondinskoye
# Processing Record 10 of Set 6 | havelock
# Processing Record 11 of Set 6 | noumea
# Processing Record 12 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 13 of Set 6 | aykhal
# Processing Record 14 of Set 6 | mar del plata
# Processing Record 15 of Set 6 | beloha
# Processing Record 16 of Set 6 | mazatlan
# Processing Record 17 of Set 6 | sandwick
# Processing Record 18 of Set 6 | olinda
# Processing Record 19 of Set 6 | ust-nera
# Processing Record 20 of Set 6 | harper
# Processing Record 21 of Set 6 | tsaratanana
# Processing Record 22 of Set 6 | port augusta
# Processing Record 23 of Set 6 | podlesnoye
# Processing Record 24 of Set 6 | lloret de mar
# Processing Record 25 of Set 6 | ketchikan
# Processing Record 26 of Set 6 | baherden
# Processing Record 27 of Set 6 | katsuura
# Processing Record 28 of Set 6 | soyo
# Processing Record 29 of Set 6 | tyup
# Processing Record 30 of Set 6 | jiazi
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | payson
# Processing Record 33 of Set 6 | awbari
# Processing Record 34 of Set 6 | vardo
# Processing Record 35 of Set 6 | bhatapara
# Processing Record 36 of Set 6 | umm lajj
# Processing Record 37 of Set 6 | salinopolis
# Processing Record 38 of Set 6 | eravur
# Processing Record 39 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 6 | kargasok
# Processing Record 41 of Set 6 | lao cai
# Processing Record 42 of Set 6 | malartic
# Processing Record 43 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 6 | bitung
# Processing Record 45 of Set 6 | eenhana
# Processing Record 46 of Set 6 | constitucion
# Processing Record 47 of Set 6 | namibe
# Processing Record 48 of Set 6 | cap malheureux
# Processing Record 49 of Set 6 | mahajanga
# Processing Record 50 of Set 6 | biltine
# Processing Record 1 of Set 7 | college
# Processing Record 2 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 3 of Set 7 | nome
# Processing Record 4 of Set 7 | djambala
# Processing Record 5 of Set 7 | roseburg
# Processing Record 6 of Set 7 | weihe
# Processing Record 7 of Set 7 | torbay
# Processing Record 8 of Set 7 | chokurdakh
# Processing Record 9 of Set 7 | georgetown
# Processing Record 10 of Set 7 | tura
# Processing Record 11 of Set 7 | huntsville
# Processing Record 12 of Set 7 | hami
# Processing Record 13 of Set 7 | tondano
# Processing Record 14 of Set 7 | ribnitz-damgarten
# Processing Record 15 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 16 of Set 7 | moree
# Processing Record 17 of Set 7 | panguna
# Processing Record 18 of Set 7 | qixia
# Processing Record 19 of Set 7 | masvingo
# Processing Record 20 of Set 7 | antofagasta
# Processing Record 21 of Set 7 | talnakh
# Processing Record 22 of Set 7 | vestmannaeyjar
# Processing Record 23 of Set 7 | gizo
# Processing Record 24 of Set 7 | husavik
# Processing Record 25 of Set 7 | lakatoro
# Processing Record 26 of Set 7 | kalabo
# Processing Record 27 of Set 7 | portland
# Processing Record 28 of Set 7 | chaumont
# Processing Record 29 of Set 7 | kununurra
# Processing Record 30 of Set 7 | cristalina
# Processing Record 31 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 7 | aksum
# Processing Record 33 of Set 7 | vreed en hoop
# City not found. Skipping...
# Processing Record 34 of Set 7 | zacler
# Processing Record 35 of Set 7 | kashi
# Processing Record 36 of Set 7 | ypsilanti
# Processing Record 37 of Set 7 | karcsa
# Processing Record 38 of Set 7 | marsh harbour
# Processing Record 39 of Set 7 | alofi
# Processing Record 40 of Set 7 | bandarbeyla
# Processing Record 41 of Set 7 | llandrindod wells
# Processing Record 42 of Set 7 | eureka
# Processing Record 43 of Set 7 | helong
# Processing Record 44 of Set 7 | berezovyy
# Processing Record 45 of Set 7 | kodiak
# Processing Record 46 of Set 7 | bontang
# Processing Record 47 of Set 7 | tucuman
# Processing Record 48 of Set 7 | boca do acre
# Processing Record 49 of Set 7 | katobu
# Processing Record 50 of Set 7 | manokwari
# Processing Record 1 of Set 8 | ufa
# Processing Record 2 of Set 8 | vao
# Processing Record 3 of Set 8 | bundaberg
# Processing Record 4 of Set 8 | galle
# Processing Record 5 of Set 8 | nadym
# Processing Record 6 of Set 8 | maldonado
# Processing Record 7 of Set 8 | krasnoselkup
# Processing Record 8 of Set 8 | dingle
# Processing Record 9 of Set 8 | nantes
# Processing Record 10 of Set 8 | benemerito de las americas
# Processing Record 11 of Set 8 | kungurtug
# Processing Record 12 of Set 8 | nabire
# Processing Record 13 of Set 8 | uvalde
# Processing Record 14 of Set 8 | damara
# Processing Record 15 of Set 8 | bambous virieux
# Processing Record 16 of Set 8 | nykoping
# Processing Record 17 of Set 8 | rabaul
# Processing Record 18 of Set 8 | rodrigues alves
# Processing Record 19 of Set 8 | olonets
# Processing Record 20 of Set 8 | kyrylivka
# Processing Record 21 of Set 8 | robertsport
# Processing Record 22 of Set 8 | kamiiso
# Processing Record 23 of Set 8 | mariani
# Processing Record 24 of Set 8 | ugoofaaru
# Processing Record 25 of Set 8 | hualmay
# Processing Record 26 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 27 of Set 8 | zhob
# Processing Record 28 of Set 8 | cugir
# Processing Record 29 of Set 8 | fier
# Processing Record 30 of Set 8 | zabaykalsk
# Processing Record 31 of Set 8 | kismayo
# Processing Record 32 of Set 8 | lagoa
# Processing Record 33 of Set 8 | cherskiy
# Processing Record 34 of Set 8 | karpathos
# Processing Record 35 of Set 8 | rundu
# Processing Record 36 of Set 8 | eyl
# Processing Record 37 of Set 8 | tilichiki
# Processing Record 38 of Set 8 | kikwit
# Processing Record 39 of Set 8 | sitka
# Processing Record 40 of Set 8 | almaty
# Processing Record 41 of Set 8 | aksarka
# Processing Record 42 of Set 8 | okhotsk
# Processing Record 43 of Set 8 | contamana
# Processing Record 44 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 8 | lebu
# Processing Record 46 of Set 8 | booue
# Processing Record 47 of Set 8 | salur
# Processing Record 48 of Set 8 | wanning
# Processing Record 49 of Set 8 | kulunda
# Processing Record 50 of Set 8 | bermejo
# Processing Record 1 of Set 9 | ayagoz
# Processing Record 2 of Set 9 | sisimiut
# Processing Record 3 of Set 9 | stara moravica
# Processing Record 4 of Set 9 | maceio
# Processing Record 5 of Set 9 | mezen
# Processing Record 6 of Set 9 | lorengau
# Processing Record 7 of Set 9 | braco do norte
# Processing Record 8 of Set 9 | sungairaya
# Processing Record 9 of Set 9 | gayny
# Processing Record 10 of Set 9 | chulym
# Processing Record 11 of Set 9 | san andres
# Processing Record 12 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 13 of Set 9 | arman
# Processing Record 14 of Set 9 | dunedin
# Processing Record 15 of Set 9 | dombarovskiy
# Processing Record 16 of Set 9 | sao joao da barra
# Processing Record 17 of Set 9 | inhambane
# Processing Record 18 of Set 9 | port shepstone
# Processing Record 19 of Set 9 | boffa
# Processing Record 20 of Set 9 | brainerd
# Processing Record 21 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 9 | rabo de peixe
# Processing Record 23 of Set 9 | aranos
# Processing Record 24 of Set 9 | marang
# Processing Record 25 of Set 9 | price
# Processing Record 26 of Set 9 | aswan
# Processing Record 27 of Set 9 | lovington
# Processing Record 28 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 29 of Set 9 | kenora
# Processing Record 30 of Set 9 | svetlyy
# Processing Record 31 of Set 9 | oga
# Processing Record 32 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 9 | dongying
# Processing Record 34 of Set 9 | yazoo city
# Processing Record 35 of Set 9 | maxixe
# Processing Record 36 of Set 9 | ocseny
# Processing Record 37 of Set 9 | grootfontein
# Processing Record 38 of Set 9 | libreville
# Processing Record 39 of Set 9 | port hedland
# Processing Record 40 of Set 9 | mortka
# Processing Record 41 of Set 9 | vangaindrano
# Processing Record 42 of Set 9 | carmen
# Processing Record 43 of Set 9 | mocuba
# Processing Record 44 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 9 | roald
# Processing Record 46 of Set 9 | crewe
# Processing Record 47 of Set 9 | muisne
# Processing Record 48 of Set 9 | port macquarie
# Processing Record 49 of Set 9 | xining
# Processing Record 50 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 10 | maniitsoq
# Processing Record 2 of Set 10 | cardston
# Processing Record 3 of Set 10 | prince albert
# Processing Record 4 of Set 10 | moron
# Processing Record 5 of Set 10 | kulotino
# Processing Record 6 of Set 10 | nokaneng
# Processing Record 7 of Set 10 | wanaka
# Processing Record 8 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 10 | lakes entrance
# Processing Record 10 of Set 10 | ust-tsilma
# Processing Record 11 of Set 10 | avera
# Processing Record 12 of Set 10 | orange cove
# Processing Record 13 of Set 10 | khonsa
# Processing Record 14 of Set 10 | merauke
# Processing Record 15 of Set 10 | ushtobe
# Processing Record 16 of Set 10 | semily
# Processing Record 17 of Set 10 | hovd
# Processing Record 18 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 10 | ixtapa
# Processing Record 20 of Set 10 | liverpool
# Processing Record 21 of Set 10 | surandai
# Processing Record 22 of Set 10 | kloulklubed
# Processing Record 23 of Set 10 | copiapo
# Processing Record 24 of Set 10 | zhigansk
# Processing Record 25 of Set 10 | nizhnevartovsk
# Processing Record 26 of Set 10 | bengkulu
# Processing Record 27 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 10 | beisfjord
# Processing Record 29 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 10 | souris
# Processing Record 31 of Set 10 | narsaq
# Processing Record 32 of Set 10 | kefamenanu
# Processing Record 33 of Set 10 | verkhniy uslon
# Processing Record 34 of Set 10 | bafq
# Processing Record 35 of Set 10 | galveston
# Processing Record 36 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | ajdabiya
# Processing Record 38 of Set 10 | makakilo city
# Processing Record 39 of Set 10 | sioux lookout
# Processing Record 40 of Set 10 | boa vista
# Processing Record 41 of Set 10 | sorland
# Processing Record 42 of Set 10 | arequipa
# Processing Record 43 of Set 10 | bure
# Processing Record 44 of Set 10 | oriximina
# Processing Record 45 of Set 10 | tashtyp
# Processing Record 46 of Set 10 | tacarigua
# Processing Record 47 of Set 10 | tauramena
# Processing Record 48 of Set 10 | alim
# Processing Record 49 of Set 10 | quelimane
# Processing Record 50 of Set 10 | esso
# Processing Record 1 of Set 11 | astana
# Processing Record 2 of Set 11 | pangnirtung
# Processing Record 3 of Set 11 | talcahuano
# Processing Record 4 of Set 11 | aklavik
# Processing Record 5 of Set 11 | saint-pierre
# Processing Record 6 of Set 11 | dolores
# Processing Record 7 of Set 11 | hamilton
# Processing Record 8 of Set 11 | whitley bay
# Processing Record 9 of Set 11 | saint-francois
# Processing Record 10 of Set 11 | deli tua
# Processing Record 11 of Set 11 | kidal
# Processing Record 12 of Set 11 | xinqing
# Processing Record 13 of Set 11 | haines junction
# Processing Record 14 of Set 11 | pacific grove
# Processing Record 15 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 11 | takaka
# Processing Record 17 of Set 11 | dalvik
# Processing Record 18 of Set 11 | biskamzha
# Processing Record 19 of Set 11 | lola
# Processing Record 20 of Set 11 | paita
# Processing Record 21 of Set 11 | lasa
# Processing Record 22 of Set 11 | finschhafen
# Processing Record 23 of Set 11 | faya
# Processing Record 24 of Set 11 | kutum
# Processing Record 25 of Set 11 | mount gambier
# Processing Record 26 of Set 11 | yinchuan
# Processing Record 27 of Set 11 | ferrol
# Processing Record 28 of Set 11 | kapiri mposhi
# Processing Record 29 of Set 11 | rio gallegos
# Processing Record 30 of Set 11 | saint-joseph
# Processing Record 31 of Set 11 | dera bugti
# Processing Record 32 of Set 11 | killybegs
# Processing Record 33 of Set 11 | ambon
# Processing Record 34 of Set 11 | chipinge
# Processing Record 35 of Set 11 | bairiki
# Processing Record 36 of Set 11 | bendigo
# Processing Record 37 of Set 11 | sarangani
# Processing Record 38 of Set 11 | great yarmouth
# Processing Record 39 of Set 11 | boyuibe
# Processing Record 40 of Set 11 | miandrivazo
# Processing Record 41 of Set 11 | sorong
# Processing Record 42 of Set 11 | almenara
# Processing Record 43 of Set 11 | ewa beach
# Processing Record 44 of Set 11 | sosnovo-ozerskoye
# Processing Record 45 of Set 11 | ostrovnoy
# Processing Record 46 of Set 11 | jalu
# Processing Record 47 of Set 11 | chabahar
# Processing Record 48 of Set 11 | daru
# Processing Record 49 of Set 11 | blagodatnoye
# Processing Record 50 of Set 11 | bowen
# Processing Record 1 of Set 12 | san ignacio
# Processing Record 2 of Set 12 | brae
# Processing Record 3 of Set 12 | byron bay
# Processing Record 4 of Set 12 | kenai
# Processing Record 5 of Set 12 | aden
# Processing Record 6 of Set 12 | entre rios
# Processing Record 7 of Set 12 | morgan city
# Processing Record 8 of Set 12 | lerik
# Processing Record 9 of Set 12 | gwadar
# Processing Record 10 of Set 12 | sao francisco do sul
# Processing Record 11 of Set 12 | port-gentil
# Processing Record 12 of Set 12 | te anau
# Processing Record 13 of Set 12 | taoudenni
# Processing Record 14 of Set 12 | oytal
# Processing Record 15 of Set 12 | lewiston
# Processing Record 16 of Set 12 | magadan
# Processing Record 17 of Set 12 | bozdar
# Processing Record 18 of Set 12 | tyrma
# Processing Record 19 of Set 12 | hoima
# Processing Record 20 of Set 12 | tazovskiy
# Processing Record 21 of Set 12 | annau
# Processing Record 22 of Set 12 | casma
# Processing Record 23 of Set 12 | brumado
# Processing Record 24 of Set 12 | zhoucheng
# Processing Record 25 of Set 12 | surt
# Processing Record 26 of Set 12 | wajima
# Processing Record 27 of Set 12 | danielskuil
# Processing Record 28 of Set 12 | eugene
# Processing Record 29 of Set 12 | birao
# Processing Record 30 of Set 12 | rampura
# Processing Record 31 of Set 12 | alugan
# Processing Record 32 of Set 12 | pokrovsk
# Processing Record 33 of Set 12 | ahuimanu
# Processing Record 34 of Set 12 | bonavista
# Processing Record 35 of Set 12 | palkaka
# City not found. Skipping...
# Processing Record 36 of Set 12 | matay
# Processing Record 37 of Set 12 | bima
# Processing Record 38 of Set 12 | ust-kuyga
# Processing Record 39 of Set 12 | santa marta
# Processing Record 40 of Set 12 | redmond
# Processing Record 41 of Set 12 | kamen-rybolov
# Processing Record 42 of Set 12 | antsohihy
# Processing Record 43 of Set 12 | miri
# Processing Record 44 of Set 12 | half moon bay
# Processing Record 45 of Set 12 | bathsheba
# Processing Record 46 of Set 12 | clinton
# Processing Record 47 of Set 12 | angoche
# Processing Record 48 of Set 12 | zhongshu
# Processing Record 49 of Set 12 | vila
# Processing Record 50 of Set 12 | sid
# Processing Record 1 of Set 13 | camocim
# Processing Record 2 of Set 13 | jaguarao
# Processing Record 3 of Set 13 | mayo
# Processing Record 4 of Set 13 | oruro
# Processing Record 5 of Set 13 | filingue
# Processing Record 6 of Set 13 | resavica
# Processing Record 7 of Set 13 | pedernales
# Processing Record 8 of Set 13 | bay roberts
# Processing Record 9 of Set 13 | richards bay
# Processing Record 10 of Set 13 | wloszczowa
# Processing Record 11 of Set 13 | oron
# Processing Record 12 of Set 13 | arkhangelsk
# Processing Record 13 of Set 13 | hede
# Processing Record 14 of Set 13 | comodoro rivadavia
# Processing Record 15 of Set 13 | padang
# Processing Record 16 of Set 13 | luena
# Processing Record 17 of Set 13 | nouakchott
# Processing Record 18 of Set 13 | shakhtinsk
# Processing Record 19 of Set 13 | katherine
# Processing Record 20 of Set 13 | havoysund
# Processing Record 21 of Set 13 | wattegama
# Processing Record 22 of Set 13 | zavodskoy
# Processing Record 23 of Set 13 | rawson
# Processing Record 24 of Set 13 | kirakira
# Processing Record 25 of Set 13 | hambantota
# Processing Record 26 of Set 13 | wagar
# Processing Record 27 of Set 13 | naryan-mar
# Processing Record 28 of Set 13 | menemen
# Processing Record 29 of Set 13 | arrifes
# Processing Record 30 of Set 13 | vostok
# Processing Record 31 of Set 13 | kavaratti
# Processing Record 32 of Set 13 | goundi
# Processing Record 33 of Set 13 | umm kaddadah
# Processing Record 34 of Set 13 | umea
# Processing Record 35 of Set 13 | sao felix do xingu
# Processing Record 36 of Set 13 | kitimat
# Processing Record 37 of Set 13 | saskatoon
# Processing Record 38 of Set 13 | tiznit
# Processing Record 39 of Set 13 | tarsus
# Processing Record 40 of Set 13 | andros town
# Processing Record 41 of Set 13 | berdigestyakh
# Processing Record 42 of Set 13 | ilo
# Processing Record 43 of Set 13 | shuangyang
# Processing Record 44 of Set 13 | kalemie
# Processing Record 45 of Set 13 | dargaville
# Processing Record 46 of Set 13 | victor harbor
# Processing Record 47 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 13 | kaliua
# Processing Record 49 of Set 13 | nedjo
# Processing Record 50 of Set 13 | atambua
# Processing Record 1 of Set 14 | estepona
# Processing Record 2 of Set 14 | chippewa falls
# Processing Record 3 of Set 14 | ekibastuz
# Processing Record 4 of Set 14 | catio
# Processing Record 5 of Set 14 | vestmanna
# Processing Record 6 of Set 14 | huambo
# Processing Record 7 of Set 14 | nurota
# Processing Record 8 of Set 14 | shibarghan
# City not found. Skipping...
# Processing Record 9 of Set 14 | wolbrom
# Processing Record 10 of Set 14 | salantai
# Processing Record 11 of Set 14 | kushima
# Processing Record 12 of Set 14 | chato
# Processing Record 13 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 14 of Set 14 | pozo colorado
# Processing Record 15 of Set 14 | frederico westphalen
# Processing Record 16 of Set 14 | cayenne
# Processing Record 17 of Set 14 | whyalla
# Processing Record 18 of Set 14 | camopi
# Processing Record 19 of Set 14 | undory
# Processing Record 20 of Set 14 | sanmenxia
# Processing Record 21 of Set 14 | tianpeng
# Processing Record 22 of Set 14 | kaputa
# Processing Record 23 of Set 14 | garm
# City not found. Skipping...
# Processing Record 24 of Set 14 | orlik
# Processing Record 25 of Set 14 | isakly
# Processing Record 26 of Set 14 | kaeo
# Processing Record 27 of Set 14 | palmer
# Processing Record 28 of Set 14 | atar
# Processing Record 29 of Set 14 | batagay
# Processing Record 30 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 31 of Set 14 | kindu
# Processing Record 32 of Set 14 | luan
# Processing Record 33 of Set 14 | tanout
# Processing Record 34 of Set 14 | paciran
# Processing Record 35 of Set 14 | shingu
# Processing Record 36 of Set 14 | rosarito
# Processing Record 37 of Set 14 | anapolis
# Processing Record 38 of Set 14 | marawi
# Processing Record 39 of Set 14 | kosterevo
# Processing Record 40 of Set 14 | siniscola
# Processing Record 41 of Set 14 | yar-sale
# Processing Record 42 of Set 14 | tolaga bay
# Processing Record 43 of Set 14 | eskisehir
# Processing Record 44 of Set 14 | cockburn town
# Processing Record 45 of Set 14 | burns lake
# Processing Record 46 of Set 14 | ardakan
# Processing Record 47 of Set 14 | yuanping
# Processing Record 48 of Set 14 | vitkov
# Processing Record 49 of Set 14 | leshan
# Processing Record 50 of Set 14 | berlevag
# Processing Record 1 of Set 15 | yakeshi
# Processing Record 2 of Set 15 | touros
# Processing Record 3 of Set 15 | rosario do sul
# Processing Record 4 of Set 15 | jieshi
# Processing Record 5 of Set 15 | northam
# Processing Record 6 of Set 15 | dodge city
# Processing Record 7 of Set 15 | yagodnoye
# Processing Record 8 of Set 15 | yulara
# Processing Record 9 of Set 15 | faridkot
# Processing Record 10 of Set 15 | tirupati
# Processing Record 11 of Set 15 | luanda
# Processing Record 12 of Set 15 | sault sainte marie
# Processing Record 13 of Set 15 | oum hadjer
# Processing Record 14 of Set 15 | broome
# Processing Record 15 of Set 15 | cascais
# Processing Record 16 of Set 15 | assomada
# Processing Record 17 of Set 15 | jimenez
# Processing Record 18 of Set 15 | zakupne
# Processing Record 19 of Set 15 | coos bay
# Processing Record 20 of Set 15 | avdon
# Processing Record 21 of Set 15 | gniezno
# Processing Record 22 of Set 15 | paracuru
# Processing Record 23 of Set 15 | burnie
# Processing Record 24 of Set 15 | kuhestan
# City not found. Skipping...
# Processing Record 25 of Set 15 | nara
# Processing Record 26 of Set 15 | slave lake
# Processing Record 27 of Set 15 | ourossogui
# Processing Record 28 of Set 15 | yangjiang
# Processing Record 29 of Set 15 | acandi
# Processing Record 30 of Set 15 | vanavara
# Processing Record 31 of Set 15 | argayash
# Processing Record 32 of Set 15 | nemuro
# Processing Record 33 of Set 15 | newport
# Processing Record 34 of Set 15 | dallas
# Processing Record 35 of Set 15 | thiruvananthapuram
# Processing Record 36 of Set 15 | ayr
# Processing Record 37 of Set 15 | codrington
# Processing Record 38 of Set 15 | meadow lake
# Processing Record 39 of Set 15 | waddan
# Processing Record 40 of Set 15 | maragogi
# Processing Record 41 of Set 15 | ngaoundere
# Processing Record 42 of Set 15 | lucapa
# Processing Record 43 of Set 15 | cooma
# Processing Record 44 of Set 15 | diamantino
# Processing Record 45 of Set 15 | sayyan
# Processing Record 46 of Set 15 | hervey bay
# Processing Record 47 of Set 15 | ossora
# Processing Record 48 of Set 15 | turukhansk
# Processing Record 49 of Set 15 | midyat
# Processing Record 50 of Set 15 | mmabatho
# Processing Record 1 of Set 16 | kasongo
# Processing Record 2 of Set 16 | mahaicony
# City not found. Skipping...
# Processing Record 3 of Set 16 | aksu
# Processing Record 4 of Set 16 | challapata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp Current Description  Humidity  \
# 0      Champerico  14.30  -91.92     84.20     overcast clouds        79
# 1          Vanimo  -2.67  141.30     78.03          light rain        82
# 2           Bluff -46.60  168.33     39.99     overcast clouds        97
# 3         Tortoli  39.93    9.66     84.20          few clouds        94
# 4     Port Alfred -33.59   26.89     61.92           clear sky        60
# 5        Imbituba -28.24  -48.67     64.40           clear sky        45
# 6  Ribeira Grande  38.52  -28.70     75.20    scattered clouds        73
# 7    Golyshmanovo  56.40   68.37     51.46    scattered clouds        98
# 8           Bilma  18.69   12.92     98.78    scattered clouds        26
# 9         Rikitea -23.12 -134.97     66.76    scattered clouds        71
#
#    Cloudiness  Wind Speed Country
# 0          90        6.93      GT
# 1          17        3.67      PG
# 2          94        9.69      NZ
# 3          20        5.82      IT
# 4           0        4.14      ZA
# 5           0        9.17      BR
# 6          40        8.05      PT
# 7          25        7.83      RU
# 8          43        4.23      NE
# 9          28       19.28      PF

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
